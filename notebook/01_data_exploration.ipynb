# %% [markdown]
# <a href="https://colab.research.google.com/github/Balaji5359/learning-patterns-classroom-strategy/blob/main/notebook/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration – Learning Patterns & Classroom Strategy
#
# ## Objective
# - Understand the dataset structure
# - Identify academic, engagement, and behavioral features
# - Observe early signals related to student performance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")

# %%
df = pd.read_csv("/content/student_data.csv")
df.head()

df = pd.read_csv("student_data.csv")

# %%
print("Dataset Shape:", df.shape)
df.info()
# Out:
# Dataset Shape: (6395, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6395 entries, 0 to 6394
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         6395 non-null   object
#  1   sex            6395 non-null   object
#  2   age            6395 non-null   int64
#  3   address        6395 non-null   object
#  4   famsize        6395 non-null   object
#  5   Pstatus        6395 non-null   object
#  6   Medu           6395 non-null   int64
#  7   Fedu           6395 non-null   int64
#  8   Mjob           6395 non-null   object
#  9   Fjob           6395 non-null   object
#  10  reason         6395 non-null   object
#  11  guardian       6395 non-null   object
#  12  traveltime     6395 non-null   int64
#  13  studytime      6395 non-null   int64
#  14  failures       6395 non-null   int64
#  15  schoolsup      6395 non-null   object
#  16  famsup         6395 non-null   object
# ...

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  6395.000000  6395.000000  6395.000000  6395.000000  6395.000000
# mean     18.393276     2.056450     2.028772     2.435496     2.481783
# std       2.265665     1.416568     1.401366     1.118848     1.104108
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     1.000000     1.000000     1.000000     2.000000
# 50%      18.000000     2.000000     2.000000     2.000000     2.000000
# 75%      20.000000     3.000000     3.000000     3.000000     3.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  6395.000000  6395.000000  6395.000000  6395.000000  6395.000000
# mean      0.526349     3.047068     2.997342     2.972791     2.918217
# std       0.938882     1.400592     1.394555     1.396590     1.435084
# ...

# %% [markdown]
# ## Feature Categorization
#
# ### Academic Features
# - studytime
# - failures
# - absences
# - G1, G2, G3
#
# ### Engagement Features
# - schoolsup
# - famsup
# - activities
# - internet
# - higher
#
# ### Behavioral & Lifestyle Features
# - goout
# - Dalc
# - Walc
# - freetime
# - health
#
# ### Demographic & Contextual Features
# - age
# - sex
# - address
# - family size
# - parental education

# %%
sns.histplot(df["G3"], kde=True)
plt.title("Distribution of Final Grade (G3)")
plt.show()

# %%
sns.boxplot(x="studytime", y="G3", data=df)
plt.title("Study Time vs Final Grade")
plt.show()

# %%
df.isnull().sum()
# Out:
# school           0
# sex              0
# age              0
# address          0
# famsize          0
# Pstatus          0
# Medu             0
# Fedu             0
# Mjob             0
# Fjob             0
# reason           0
# guardian         0
# traveltime       0
# studytime        0
# failures         0
# schoolsup        0
# famsup           0
# paid             0
# activities       0
# nursery          0
# higher           0
# internet         0
# romantic         0
# famrel           0
# freetime         0
# goout            0
# Dalc             0
# Walc             0
# health           0
# absences         0
# G1               0
# G2               0
# G3               0
# part_time_job    0
# dtype: int64

# %% [markdown]
# ## Initial Observations
#
# - Dataset contains both categorical and numerical features
# - No direct label for learning style → clustering is suitable
# - Academic effort and engagement appear related to final grades
# - Dataset is suitable for explainable ML approaches
